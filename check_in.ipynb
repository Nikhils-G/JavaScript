# %%
import pandas as pd

# %%
t_in=pd.read_csv(r"C:\Users\Nikhil Sukthe\Downloads\Case Study\Case Study\Training Data\Train_Inpatientdata-1542865627584.csv")

# %%
t_in.size
# Out:
# 1214220

# %%
t_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
t_in.tail()
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 40469                    7000          PHY345332          PHY319565
# 40470                    4000          PHY342806          PHY365497
# 40471                    3000          PHY423220          PHY332752
# 40472                    5000          PHY353156                NaN
# 40473                   15000          PHY431177          PHY352941
#
#       OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 40469            NaN  2009-09-28  ...              79092               70704
# ...

# %%
t_out=pd.read_csv(r"C:\Users\Nikhil Sukthe\Downloads\Case Study\Case Study\Training Data\Train_Outpatientdata-1542865627584.csv")

# %%
t_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# ...

# %%
t_out.tail()
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 517732  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 517733  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 517734  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 517735  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 517736  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 517732                     800          PHY364188          PHY364188
# 517733                     400          PHY423019          PHY332284
# 517734                      60          PHY361063                NaN
# 517735                      70          PHY403198                NaN
# 517736                      80          PHY419379                NaN
#
#        OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 517732      PHY385752               2163  ...                NaN
# ...

# %%
t_ben=pd.read_csv(r"C:\Users\Nikhil Sukthe\Downloads\Case Study\Case Study\Training Data\Train_Beneficiarydata-1542865627584.csv")

# %%
t_ben.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# ...

# %%
t_ben.tail()
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 138551  BENE159194  1939-07-01  NaN       1     1                     0
# 138552  BENE159195  1938-12-01  NaN       2     1                     0
# 138553  BENE159196  1916-06-01  NaN       2     1                     0
# 138554  BENE159197  1930-01-01  NaN       1     1                     0
# 138555  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 138551     39     140                   12                   12  ...
# 138552     49     530                   12                   12  ...
# 138553      6     150                   12                   12  ...
# 138554     16     560                   12                   12  ...
# 138555     21      20                   12                   12  ...
#
#         ChronicCond_Depression  ChronicCond_Diabetes  \
# 138551                       2                     2
# ...

# %%
train=pd.read_csv(r"C:\Users\Nikhil Sukthe\Downloads\Case Study\Case Study\Training Data\Train-1542865627584.csv")

# %%
train.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
train.tail()
# Out:
#       Provider PotentialFraud
# 5405  PRV57759             No
# 5406  PRV57760             No
# 5407  PRV57761             No
# 5408  PRV57762             No
# 5409  PRV57763             No
